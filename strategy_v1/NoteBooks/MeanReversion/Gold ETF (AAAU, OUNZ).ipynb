# %% [markdown]
# # Gold ETF Mean Reversion AAAU OUNZ
#
# ### Failed
#
# - The spread is too tight, the returs from pairs trading can't justify the commission

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

import plotly.graph_objects as go
import plotly
import warnings
import yfinance as yf

from account import Futu
from datetime import datetime
from plotly.subplots import make_subplots
from utils.logging import get_logger
from utils.data_helper import get_today
from tqdm import tqdm
from itertools import cycle
from strategy_v1 import InterdayPairsMeanReversion, InterdayMeanReversion
from itertools import combinations

warnings.filterwarnings('ignore')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 200

logger = get_logger('Mean Reversion Strategy')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start_date = datetime(2021,1,1)
end_date = get_today(-1)
symbols = ['AAAU','OUNZ']

# %%
strategy = InterdayPairsMeanReversion()
strategy.set_stock_universe(symbols)
strategy.set_start_date(start_date)
strategy.set_end_date(end_date)

strategy.z_entry = 2
strategy.z_exit = 0

strategy.preprocess_data()
strategy.generate_position()
strategy.backtest_summary()
# Out:
# [*********************100%***********************]  2 of 2 completed
# 2024-02-17 18:24:12,903 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-01-03
# 2024-02-17 18:24:12,918 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-01-26
# 2024-02-17 18:24:12,928 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-02-09
# 2024-02-17 18:24:12,937 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-02-24
# 2024-02-17 18:24:12,947 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-03-10
# 2024-02-17 18:24:12,956 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-03-24
# 2024-02-17 18:24:12,967 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-04-07
# 2024-02-17 18:24:12,976 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-04-22
# 2024-02-17 18:24:12,985 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-05-06
# 2024-02-17 18:24:12,994 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-05-20
# 2024-02-17 18:24:13,003 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-06-06
# 2024-02-17 18:24:13,013 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-06-21
# 2024-02-17 18:24:13,021 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-07-06
# 2024-02-17 18:24:13,030 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-07-20
# 2024-02-17 18:24:13,039 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-08-03
# 2024-02-17 18:24:13,048 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-08-17
# 2024-02-17 18:24:13,057 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2022-08-31
# 2024-02-17 18:24:13,068 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-09-15
# 2024-02-17 18:24:13,080 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-09-29
# 2024-02-17 18:24:13,092 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-10-13
# 2024-02-17 18:24:13,104 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-10-27
# 2024-02-17 18:24:13,113 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-11-10
# 2024-02-17 18:24:13,122 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-11-25
# 2024-02-17 18:24:13,131 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-12-09
# 2024-02-17 18:24:13,140 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2022-12-23
# 2024-02-17 18:24:13,148 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-01-10
# 2024-02-17 18:24:13,157 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-01-25
# 2024-02-17 18:24:13,167 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-02-08
# 2024-02-17 18:24:13,176 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-02-23
# 2024-02-17 18:24:13,184 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-03-09
# 2024-02-17 18:24:13,194 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-03-23
# 2024-02-17 18:24:13,203 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-04-06
# 2024-02-17 18:24:13,218 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-05-04
# 2024-02-17 18:24:13,226 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-05-18
# 2024-02-17 18:24:13,235 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-06-02
# 2024-02-17 18:24:13,244 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-06-16
# 2024-02-17 18:24:13,253 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-07-03
# 2024-02-17 18:24:13,262 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-07-18
# 2024-02-17 18:24:13,271 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-08-01
# 2024-02-17 18:24:13,281 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-08-17
# 2024-02-17 18:24:13,290 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-08-31
# 2024-02-17 18:24:13,299 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-09-15
# 2024-02-17 18:24:13,309 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-09-29
# 2024-02-17 18:24:13,318 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-10-13
# 2024-02-17 18:24:13,334 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-10-27
# 2024-02-17 18:24:13,350 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-11-21
# 2024-02-17 18:24:13,361 - Interday Pairs Mean Reversion - INFO - Price series is not cointegrated, do not trade and refresh the eigenvector: 2023-12-06
# 2024-02-17 18:24:13,371 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2023-12-20
# 2024-02-17 18:24:13,380 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2024-01-05
# 2024-02-17 18:24:13,390 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2024-01-22
# 2024-02-17 18:24:13,400 - Interday Pairs Mean Reversion - INFO - Rebalance portfolio based on Johanson Test at rank 1: 2024-02-05
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                          Interday Pairs Mean Reversion      ^SPX     ^IXIC
# Measure
# Cumulative Return                             0.994098  1.043575  0.996390
# Annualized Return                            -0.002788  0.038289  0.030296
# Annualized Volatility                         0.003306  0.190503  0.252902
# Annualized Sharpe Ratio                     -11.476426  0.016465 -0.019203
# Maximum Drawdown                             -0.006820 -0.254251 -0.354928
