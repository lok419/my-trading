# %%
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import numpy as np
import warnings
import matplotlib.pyplot as plt
import cvxpy as cp
import scipy.stats as stats
from matplotlib.gridspec import GridSpec
from Utils import *
from tqdm import tqdm
from datetime import datetime, date
from pandas.tseries.offsets import BDay

warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.4f}'.format

# %%
start_date = datetime(2018,1,1)
end_date = datetime.today()
tickers = ['DXJ', 'EWJ']

# %%
df = yf.download(['DXJ', 'EWJ'], auto_adjust=True, start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df_close = df['Close']
df_return = df_close / df_close.shift(1) - 1

# %%
performance_summary_plot(df_return['DXJ'], 'DXJ', benchmark=['EWJ', 'SPY', 'DXJS'])
# Out:
# [*********************100%***********************]  1 of 1 completed
#                             DXJ     EWJ     SPY    DXJS
# Measure
# Cumulative Return        1.9010  1.2079  2.0006  1.8340
# Annualized Return        0.1273  0.0468  0.1352  0.1221
# Annualized Volatility    0.2054  0.1765  0.2029  0.2091
# Annualized Sharpe Ratio  0.4495  0.0672  0.4941  0.4167
# Maximum Drawdown        -0.3914 -0.3314 -0.3372 -0.3679
