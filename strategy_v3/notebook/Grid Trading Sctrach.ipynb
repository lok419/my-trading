# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from utils.data_helper import *
from utils.data import *
from utils.stats import *
from utils.performance import *
from plotly.subplots import make_subplots
from account.Binance import Binance
from binance.client import Client
from pandas.core.frame import DataFrame
import pandas as pd
import warnings
from strategy_v3.Strategy import GridArithmeticStrategy
from strategy_v3.Executor import ExecutorBinance, ExecutorBacktest
from strategy_v3.DataLoader import DataLoaderBinance
from datetime import datetime, timezone
from time import sleep

pd.set_option('display.max_rows', 100)
warnings.filterwarnings('ignore')

# %%
symbol = 'BTCUSDT'
binance = Binance()
df = binance.get_historical_instrument_price(symbol, interval='1m', start_str='1 Day ago')
plot_price_ohcl(df, symbol)

# %% [markdown]
# # Grid Trading Logic (Arithmetic)

# %% [markdown]
# ## Example of First Grid Strategy without stoploss and grid resettings
#
# - If I use the same grid without re-scaling, what would be the backtest PnL?
#
# - Limit the size of each grid order to no more than 1-2% of your account balance to reduce the risk of significant losses.
#
# - Backtest method
#
#     - Keep a structure which stores all the limits orders and determine whether it is executed or not
#
#     - At each time point, we keep track which orders are executed / not execured / be executed in this periods based on OHCL
#
#     - Finally, calculate the returns based on limit orders
#
#     - <b>the backtest way is designed in a way that is applicable for all others algo trading strategy based on many limit orders</b>

# %%
instrument = 'BTCUSDT'
interval = '5m'
lookback_period = '1 Days ago'
vol_lookback = 30
vol_scale = 1
position_size = 1
binance = Binance()

df = binance.get_historical_instrument_price(instrument, interval=interval, start_str=lookback_period)
df['Vol'] = df['Close'].diff().rolling(vol_lookback).std()
df["half_life"] = df['Close'].rolling(100).apply(lambda x: time_series_half_life(x))
df["hurst_exponent"] = df["Close"].rolling(100).apply(lambda x: time_series_hurst_exponent(x))

start_dt_offset = 150
start_dt_offset = max(start_dt_offset, vol_lookback+1)

start_dt = df['Date'].iloc[start_dt_offset]
start_px = df['Open'].iloc[start_dt_offset]
start_vol = df['Vol'].iloc[start_dt_offset-1]

grid_scales = list(range(-5,5+1,1))
grid_prices = [start_px + x * start_vol * vol_scale for x in grid_scales]

# we keep track an order list for backtest
orders_list = []
for i, px in enumerate(grid_prices):
    if grid_scales[i] == 0:
        continue

    orders_list.append({
        'price': px,
        'qty': position_size,
        'side': 'sell' if grid_scales[i] > 0 else 'buy',
        'order_dt': start_dt,
        'filled_dt': None,
        'filled': False,
        'cancelled': False,
    })

for i, row in df.iterrows():
    date = row['Date']

    if date < start_dt:
        continue

    open, close, high, low = row['Open'], row['Close'], row['High'], row['Low']    
    for i in range(len(orders_list)):
        order = orders_list[i]
        if order['filled'] == True:
            continue
        order_px = order['price']

        # order_px are within the price range in the periods
        if order_px >= low and order_px <= high:
            order['filled'] = True
            order['filled_dt'] = date
        orders_list[i] = order

# after all logic, close out leave the unfilled orders and create an market orders to close out the positions    
df_orders = pd.DataFrame(orders_list)
df_orders['net_qty'] = np.where(df_orders['side'] == 'buy', df_orders['qty'], -1 * df_orders['qty'])
df_orders['cancelled'] = ~df_orders['filled']
net_qty = df_orders[df_orders['filled'] == True]['net_qty'].sum()

if net_qty != 0:
    close_order = pd.DataFrame([{
        'price': close,
        'qty': abs(net_qty),
        'side': 'buy' if net_qty < 0 else 'sell',
        'order_dt': date,
        'filled_dt': date,
        'filled': True,
        'cancelled': False,
        'net_qty': -net_qty

    }])
    df_orders = pd.concat([df_orders, close_order])

df_orders = df_orders.sort_values(['filled_dt'])
display(df_orders)

# calculate the PNL based on filled orders
pnl = df_orders[df_orders['filled'] == True]
pnl['mv'] = -1 * pnl['net_qty'] * pnl['price']
pnl = pnl['mv'].sum()
print(pnl)

fig = make_subplots(
    rows=3, cols=1, 
    shared_xaxes=True, 
    vertical_spacing=0.1, 
    subplot_titles=[
        'Price OHLC',         
    ],         
    row_heights=[0.8, 0.2, 0.2],  
)
fig.update_layout(
    title=instrument,
    width=1500, height=1000,        
    hovermode='x',
)
colors = plotly.colors.DEFAULT_PLOTLY_COLORS
fig.add_trace(go.Candlestick(x=df["Date"], open=df["Open"], high=df["High"], low=df["Low"], close=df["Close"], name="OHLC", legendgroup='OHCL'), row=1, col=1)
fig.add_trace(go.Scatter(x=df['Date'], y=df['half_life']), row=2,col=1)
fig.add_trace(go.Scatter(x=df['Date'], y=df['hurst_exponent']), row=3,col=1)

for i, grid in enumerate(grid_prices):
    lw = 1
    if grid_scales[i] > 0:
        color = 'green'        
    elif grid_scales[i] < 0:
        color = 'red'        
    else:
        color = 'black'
        lw = 2

    fig.add_hline(y=grid, line_width=lw, line_dash="dash", line_color=color, row=1, col=1)
fig.add_vline(x=start_dt, line_width=1, line_dash="dash", row=1, col=1)
fig.update(layout_xaxis_rangeslider_visible=False)
# Out:
#           price  qty  side            order_dt           filled_dt  filled
# 5  52433.408800    1  sell 2024-02-19 07:15:00 2024-02-19 07:15:00    True  \
# 6  52482.827601    1  sell 2024-02-19 07:15:00 2024-02-19 07:25:00    True
# 4  52334.571200    1   buy 2024-02-19 07:15:00 2024-02-19 08:05:00    True
# 3  52285.152399    1   buy 2024-02-19 07:15:00 2024-02-19 08:15:00    True
# 2  52235.733599    1   buy 2024-02-19 07:15:00 2024-02-19 08:30:00    True
# 0  52136.895998    1   buy 2024-02-19 07:15:00 2024-02-19 08:45:00    True
# 1  52186.314798    1   buy 2024-02-19 07:15:00 2024-02-19 08:45:00    True
# 0  52094.010000    3  sell 2024-02-19 18:40:00 2024-02-19 18:40:00    True
# 7  52532.246401    1  sell 2024-02-19 07:15:00                 NaT   False
# 8  52581.665202    1  sell 2024-02-19 07:15:00                 NaT   False
# 9  52631.084002    1  sell 2024-02-19 07:15:00                 NaT   False
#
#    cancelled  net_qty
# 5      False       -1
# 6      False       -1
# 4      False        1
# 3      False        1
# 2      False        1
# 0      False        1
# 1      False        1
# 0      False       -3
# 7       True       -1
# 8       True       -1
# 9       True       -1
# 19.598407893252443

# %% [markdown]
# # A more comprehensive implementation
#
# 1. strategy in idle states
#
# 2. place grid orders when hurst exponent < 0.5 and half life < k intervals
#
# 3. close position when price reach stop loss -> go back to (1)
#
# 4. exit strategy when all grids orders are equally cancelled out -> go back to (1)

# %%
# Required functions. Real trading should be actual function connect the brokers API
def place_grid_orders(
        df_orders: DataFrame,
        date:datetime, 
        position_size: float,
        curent_px: float, 
        current_vol: float,                
        grid_id: int,
        vol_scale,
        vol_stoploss_scale,
    ) -> DataFrame:
    
    grid_scales = list(range(-5,5+1,1))
    grid_prices = [curent_px + x * current_vol * vol_scale for x in grid_scales]

    stoploss = (curent_px - vol_stoploss_scale * current_vol, curent_px + vol_stoploss_scale * current_vol)

    # we keep track an order list for backtest
    orders_list = []
    for i, px in enumerate(grid_prices):
        if grid_scales[i] == 0:
            continue

        orders_list.append({
            'price': px,
            'qty': position_size,
            'side': 'sell' if grid_scales[i] > 0 else 'buy',
            'order_dt': date,
            'filled_dt': None,
            'filled': False,
            'cancelled': False,
            'net_qty': -position_size if grid_scales[i] > 0 else position_size,
            'grid_id': grid_id,
            'remark': 'grid',
        })

    df_orders = pd.concat([df_orders, pd.DataFrame(orders_list)])
    return df_orders, stoploss

def cancel_all_orders(df_orders: DataFrame) -> DataFrame:
    df_orders['cancelled'] = df_orders['filled'] == False
    return df_orders

def close_out_position(
        df_orders: DataFrame, 
        date: datetime,
        close: float,
        grid_id: int,
        remark: str,
        ) -> DataFrame:    
    
    net_qty = df_orders[df_orders['filled'] == True]['net_qty'].sum()    
    if net_qty != 0:
        close_order = pd.DataFrame([{
            'price': close,
            'qty': abs(net_qty),
            'side': 'buy' if net_qty < 0 else 'sell',
            'order_dt': date,
            'filled_dt': date,
            'filled': True,
            'cancelled': False,
            'net_qty': -net_qty,
            'grid_id': grid_id,
            'remark': remark,
        }])
        df_orders = pd.concat([df_orders, close_order])
        
    return df_orders

def is_position_natural(df_orders: DataFrame) -> bool:
    last_grid = df_orders[df_orders['grid_id'] == df_orders['grid_id'].max()]
        
    filled = last_grid[last_grid['filled'] == True]
    has_filled = len(filled) > 0
    filled_net_qty = filled['net_qty'].sum()

    if has_filled and filled_net_qty == 0:
        return True
    
    return False

# this only for backtesting to replicate the fills, in reality, this is filled by brokers
def fill_orders(
        df_orders: DataFrame, 
        date:datetime, 
        low:float,
        high:float,         
        ) -> DataFrame:
    
    fill_filters = (df_orders['filled'] == False)&\
        (df_orders['cancelled'] == False)&\
        (df_orders['price'] >= low) &\
        (df_orders['price'] <= high)   

    df_orders['filled'] = np.where(fill_filters, True, df_orders['filled'])
    df_orders['filled_dt'] = pd.to_datetime(np.where(fill_filters, date, df_orders['filled_dt']))                
    return df_orders

def is_idle(df_orders: DataFrame):
    x = df_orders.copy()
    x = x[x['filled'] == False]
    x = x[x['cancelled'] == False]    
    is_idle = len(x) == 0
    return is_idle

def compute_pnl(df_orders):
    pnl = df_orders[df_orders['filled'] == True]
    assert pnl['net_qty'].sum() == 0

    pnl['mv'] = -1 * pnl['net_qty'] * pnl['price']    
    pnl_gross = pnl['mv'].sum()    
    fee = pnl['transaction_fee'].sum()    
    pnl_net = pnl_gross - fee

    return pnl_net

# %%
instrument = 'BTCUSDT'
interval = '5m'
lookback_period = '10 Days ago'

lookback = 30
vol_scale = 0.6
vol_stoploss_scale = 7
position_size = 1
binance = Binance()

df = binance.get_historical_instrument_price(instrument, interval=interval, start_str=lookback_period)
df['Vol'] = df['Close'].diff().rolling(lookback).std().shift(1)
df["half_life"] = df['Close'].rolling(100).apply(lambda x: time_series_half_life(x)).shift(1)
df["hurst_exponent"] = df["Close"].rolling(100).apply(lambda x: time_series_hurst_exponent(x)).shift(1)

# %%
grid_id = 0
df_orders = pd.DataFrame(columns=['price', 'qty', 'side', 'order_dt', 'filled_dt', 'filled', 'cancelled', 'net_qty', 'grid_id', 'remark'])
stoploss = (-float('inf'), float('inf'))

for i, row in df.iterrows():
    date = row['Date']
    hurst_exponent = row['hurst_exponent']
    open, close, high, low = row['Open'], row['Close'], row['High'], row['Low']            
    vol = row['Vol']    

    # at beginning of periods, use open price to create grid orders
    if is_idle(df_orders) and hurst_exponent < 0.5:
        grid_id += 1
        df_orders, stoploss = place_grid_orders(df_orders, date, position_size, open, vol, grid_id, vol_scale, vol_stoploss_scale)        

    # fill the orders using high and low        
    df_orders = fill_orders(df_orders, date, low, high)        

    # after filling, if position is netural, cancel all orders
    if is_position_natural(df_orders):                
        df_orders = cancel_all_orders(df_orders)        

    # finally, check the close price and determine if we need stop loss
    if not is_idle(df_orders) and (close < stoploss[0] or close > stoploss[1]):        
        df_orders = cancel_all_orders(df_orders)
        df_orders = close_out_position(df_orders, date, close, grid_id, 'stoploss')
    
df_orders = cancel_all_orders(df_orders)
df_orders = close_out_position(df_orders, date, close, grid_id, 'close')
df_orders['transaction_fee'] = np.where(df_orders['filled'] == True, df_orders['qty'] * df_orders['price'] * 0/100, 0)

pnl = compute_pnl(df_orders)
return_pct = pnl/(close*10)

print('PnL: ${:,.0f}, Return: {:.2f}%, num of orders: {:.2f}'.format(pnl, return_pct*100, len(df_orders)))
df_orders = df_orders.sort_values(['grid_id', 'filled_dt'])
# Out:
# PnL: $4,356, Return: 0.86%, num of orders: 659.00

# %%
fig = make_subplots(
    rows=3, cols=1, 
    shared_xaxes=True, 
    vertical_spacing=0.1, 
    subplot_titles=[
        'Price OHLC',     
        'Half Life',
        'Hurst Exponent',
    ],         
    row_heights=[0.8, 0.2, 0.2],  
)
fig.update_layout(
    title=instrument,
    width=1500, height=1000,        
    hovermode='x',
)
colors = plotly.colors.DEFAULT_PLOTLY_COLORS
fig.add_trace(go.Candlestick(x=df["Date"], open=df["Open"], high=df["High"], low=df["Low"], close=df["Close"], name="OHLC", legendgroup='OHCL'), row=1, col=1)
fig.add_trace(go.Scatter(x=df['Date'], y=df['half_life']), row=2,col=1)
fig.add_trace(go.Scatter(x=df['Date'], y=df['hurst_exponent']), row=3,col=1)

for i in range(df_orders['grid_id'].max()):
    temp = df_orders[df_orders['grid_id'] == i+1]
    grid_min_dt = temp['order_dt'].min()
    grid_max_dt = temp['filled_dt'].max()
    grid_prices = sorted(temp[temp['remark'] == 'grid']['price'].values)

    for i, grid in enumerate(grid_prices):
        lw = 1
        if i/2 >= 2.5:
            color = 'green'        
        else:
            color = 'red'  

        fig.add_shape(type='line', x0=grid_min_dt, x1=grid_max_dt, y0=grid, y1=grid, line=dict(color=color, dash='dash'), row=1, col=1)

filled_orders = df_orders[df_orders['filled'] == True]
filled_orders_buy = df_orders[df_orders['side'] == 'buy']
filled_orders_sell = df_orders[df_orders['side'] == 'sell']

fig.add_trace(go.Scatter(x=filled_orders_buy['filled_dt'], y=filled_orders_buy['price'], marker=dict(color='green',size=15), mode='markers', marker_symbol=5, name='Buy'),row=1, col=1)
fig.add_trace(go.Scatter(x=filled_orders_sell['filled_dt'], y=filled_orders_sell['price'], marker=dict(color='red',size=15), mode='markers', marker_symbol=6, name='Sell'),row=1, col=1)
fig.update(layout_xaxis_rangeslider_visible=False)

# %% [markdown]
# # Strategy Class

# %% [markdown]
# ## BackTest Strategy

# %%
strategy = GridArithmeticStrategy(
    instrument = 'BTCUSDT',
    interval = '5m',
    grid_size = 5,
    vol_lookback = 30,
    vol_grid_scale = 0.4,
    vol_stoploss_scale = 7,
    position_size = 100,
    hurst_exp_threshold = 0.5
)
strategy.set_price_decimal(2)
strategy.set_qty_decimal(5)
strategy.set_data_loder(DataLoaderBinance())
strategy.set_executor(ExecutorBacktest())
strategy.load_data('1 Days Ago')

# %%
df = strategy.df.copy()
for i, data in df.iterrows():
    strategy.execute(data)
strategy.close_out_positions('close', data['Close'], data['Date'])
strategy.summary(True)
# Out:
# 2024-02-24 03:12:30,192 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51046.92....
# 2024-02-24 03:12:30,202 - grid_995789 - INFO - [2024-02-23 03:35:00] filling 1 orders...
# 2024-02-24 03:12:30,208 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.53 (above threshold 0.50).
# 2024-02-24 03:12:30,209 - grid_995789 - INFO - [2024-02-23 03:40:00] filling 3 orders...
# 2024-02-24 03:12:30,214 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,220 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,226 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,231 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,235 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.56 (above threshold 0.50).
# 2024-02-24 03:12:30,240 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,253 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.54 (above threshold 0.50).
# 2024-02-24 03:12:30,258 - grid_995789 - INFO - [2024-02-23 04:15:00] filling 2 orders...
# 2024-02-24 03:12:30,270 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,280 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,294 - grid_995789 - INFO - stop loss are triggered at 51207.19.
# 2024-02-24 03:12:30,301 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,308 - grid_995789 - INFO - closing out net position of -0.00784 BTCUSDT....
# 2024-02-24 03:12:30,310 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,313 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.58 (above threshold 0.50).
# 2024-02-24 03:12:30,316 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.57 (above threshold 0.50).
# 2024-02-24 03:12:30,329 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.61 (above threshold 0.50).
# 2024-02-24 03:12:30,333 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.61 (above threshold 0.50).
# 2024-02-24 03:12:30,336 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.59 (above threshold 0.50).
# 2024-02-24 03:12:30,339 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.60 (above threshold 0.50).
# 2024-02-24 03:12:30,342 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.62 (above threshold 0.50).
# 2024-02-24 03:12:30,344 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.57 (above threshold 0.50).
# 2024-02-24 03:12:30,348 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,351 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.53 (above threshold 0.50).
# 2024-02-24 03:12:30,354 - grid_995789 - INFO - creating 10 grid orders of 0.00195 BTCUSDT at grid center price 51228.2....
# 2024-02-24 03:12:30,362 - grid_995789 - INFO - [2024-02-23 05:25:00] filling 2 orders...
# 2024-02-24 03:12:30,370 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:30,370 - grid_995789 - INFO - [2024-02-23 05:30:00] filling 2 orders...
# 2024-02-24 03:12:30,376 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.46 (below threshold 0.50).
# 2024-02-24 03:12:30,381 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.46 (below threshold 0.50).
# 2024-02-24 03:12:30,386 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:30,387 - grid_995789 - INFO - [2024-02-23 05:45:00] filling 1 orders...
# 2024-02-24 03:12:30,392 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,397 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.47 (below threshold 0.50).
# 2024-02-24 03:12:30,403 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.44 (below threshold 0.50).
# 2024-02-24 03:12:30,404 - grid_995789 - INFO - [2024-02-23 06:00:00] filling 2 orders...
# 2024-02-24 03:12:30,408 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,409 - grid_995789 - INFO - [2024-02-23 06:05:00] filling 1 orders...
# 2024-02-24 03:12:30,414 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,420 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,425 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,430 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:30,437 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.36 (below threshold 0.50).
# 2024-02-24 03:12:30,443 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.31 (below threshold 0.50).
# 2024-02-24 03:12:30,443 - grid_995789 - INFO - [2024-02-23 06:35:00] filling 1 orders...
# 2024-02-24 03:12:30,449 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:30,455 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,461 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:30,466 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:30,471 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.50 (below threshold 0.50).
# 2024-02-24 03:12:30,476 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.50 (above threshold 0.50).
# 2024-02-24 03:12:30,481 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,486 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,492 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.55 (above threshold 0.50).
# 2024-02-24 03:12:30,497 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.53 (above threshold 0.50).
# 2024-02-24 03:12:30,502 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.50 (below threshold 0.50).
# 2024-02-24 03:12:30,505 - grid_995789 - INFO - stop loss are triggered at 51105.46.
# 2024-02-24 03:12:30,505 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,507 - grid_995789 - INFO - closing out net position of 0.00195 BTCUSDT....
# 2024-02-24 03:12:30,509 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51051.11....
# 2024-02-24 03:12:30,515 - grid_995789 - INFO - [2024-02-23 07:35:00] filling 5 orders...
# 2024-02-24 03:12:30,520 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,521 - grid_995789 - INFO - [2024-02-23 07:40:00] filling 1 orders...
# 2024-02-24 03:12:30,526 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.45 (below threshold 0.50).
# 2024-02-24 03:12:30,526 - grid_995789 - INFO - [2024-02-23 07:45:00] filling 4 orders...
# 2024-02-24 03:12:30,529 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,532 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.54 (above threshold 0.50).
# 2024-02-24 03:12:30,535 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.52 (above threshold 0.50).
# 2024-02-24 03:12:30,537 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.52 (above threshold 0.50).
# 2024-02-24 03:12:30,540 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.52 (above threshold 0.50).
# 2024-02-24 03:12:30,543 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.50 (above threshold 0.50).
# 2024-02-24 03:12:30,545 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,548 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.52 (above threshold 0.50).
# 2024-02-24 03:12:30,550 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51051.11....
# 2024-02-24 03:12:30,557 - grid_995789 - INFO - [2024-02-23 08:30:00] filling 4 orders...
# 2024-02-24 03:12:30,562 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.45 (below threshold 0.50).
# 2024-02-24 03:12:30,563 - grid_995789 - INFO - [2024-02-23 08:35:00] filling 1 orders...
# 2024-02-24 03:12:30,568 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:30,573 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,576 - grid_995789 - INFO - stop loss are triggered at 50902.17.
# 2024-02-24 03:12:30,576 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,579 - grid_995789 - INFO - closing out net position of 0.0098 BTCUSDT....
# 2024-02-24 03:12:30,581 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.50 (above threshold 0.50).
# 2024-02-24 03:12:30,584 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.50 (above threshold 0.50).
# 2024-02-24 03:12:30,587 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,590 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 50919.99....
# 2024-02-24 03:12:30,597 - grid_995789 - INFO - [2024-02-23 09:05:00] filling 3 orders...
# 2024-02-24 03:12:30,604 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,605 - grid_995789 - INFO - [2024-02-23 09:10:00] filling 1 orders...
# 2024-02-24 03:12:30,608 - grid_995789 - INFO - status: NEUTRAL.
# 2024-02-24 03:12:30,609 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,611 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,614 - grid_995789 - INFO - state: IDLE, hurst_exponent is 0.52 (above threshold 0.50).
# 2024-02-24 03:12:30,617 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 50894.71....
# 2024-02-24 03:12:30,624 - grid_995789 - INFO - [2024-02-23 09:25:00] filling 4 orders...
# 2024-02-24 03:12:30,629 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.47 (below threshold 0.50).
# 2024-02-24 03:12:30,630 - grid_995789 - INFO - [2024-02-23 09:30:00] filling 1 orders...
# 2024-02-24 03:12:30,635 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,641 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.50 (below threshold 0.50).
# 2024-02-24 03:12:30,646 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.53 (above threshold 0.50).
# 2024-02-24 03:12:30,651 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.53 (above threshold 0.50).
# 2024-02-24 03:12:30,656 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.51 (above threshold 0.50).
# 2024-02-24 03:12:30,662 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.49 (below threshold 0.50).
# 2024-02-24 03:12:30,667 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.44 (below threshold 0.50).
# 2024-02-24 03:12:30,672 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:30,678 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,684 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:30,687 - grid_995789 - INFO - stop loss are triggered at 51066.54.
# 2024-02-24 03:12:30,687 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,689 - grid_995789 - INFO - closing out net position of -0.0098 BTCUSDT....
# 2024-02-24 03:12:30,691 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51119.93....
# 2024-02-24 03:12:30,704 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,705 - grid_995789 - INFO - [2024-02-23 10:30:00] filling 2 orders...
# 2024-02-24 03:12:30,708 - grid_995789 - INFO - status: NEUTRAL.
# 2024-02-24 03:12:30,708 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:30,710 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51101.19....
# 2024-02-24 03:12:30,717 - grid_995789 - INFO - [2024-02-23 10:35:00] filling 2 orders...
# 2024-02-24 03:12:30,723 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,730 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,736 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,741 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,747 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:30,748 - grid_995789 - INFO - [2024-02-23 11:00:00] filling 2 orders...
# 2024-02-24 03:12:30,753 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,759 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,765 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:30,765 - grid_995789 - INFO - [2024-02-23 11:15:00] filling 1 orders...
# 2024-02-24 03:12:30,771 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,777 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:30,783 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.46 (below threshold 0.50).
# 2024-02-24 03:12:30,788 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.45 (below threshold 0.50).
# 2024-02-24 03:12:30,794 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:30,799 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,805 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,811 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:30,817 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:30,823 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:30,828 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.36 (below threshold 0.50).
# 2024-02-24 03:12:30,829 - grid_995789 - INFO - [2024-02-23 12:10:00] filling 4 orders...
# 2024-02-24 03:12:30,836 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:30,842 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:30,842 - grid_995789 - INFO - [2024-02-23 12:20:00] filling 1 orders...
# 2024-02-24 03:12:30,845 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 50987.51....
# 2024-02-24 03:12:30,853 - grid_995789 - INFO - [2024-02-23 12:25:00] filling 3 orders...
# 2024-02-24 03:12:30,860 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:30,866 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:30,867 - grid_995789 - INFO - [2024-02-23 12:35:00] filling 1 orders...
# 2024-02-24 03:12:30,873 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,879 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,886 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:30,887 - grid_995789 - INFO - [2024-02-23 12:50:00] filling 1 orders...
# 2024-02-24 03:12:30,901 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.45 (below threshold 0.50).
# 2024-02-24 03:12:30,917 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.44 (below threshold 0.50).
# 2024-02-24 03:12:30,926 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,941 - grid_995789 - INFO - [2024-02-23 13:05:00] filling 2 orders...
# 2024-02-24 03:12:30,965 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,976 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.42 (below threshold 0.50).
# 2024-02-24 03:12:30,989 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:30,995 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,002 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,008 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,015 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,021 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.36 (below threshold 0.50).
# 2024-02-24 03:12:31,022 - grid_995789 - INFO - [2024-02-23 13:45:00] filling 1 orders...
# 2024-02-24 03:12:31,027 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,033 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,039 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,045 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,051 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,056 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,060 - grid_995789 - INFO - stop loss are triggered at 51105.8.
# 2024-02-24 03:12:31,060 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:31,063 - grid_995789 - INFO - closing out net position of -0.00392 BTCUSDT....
# 2024-02-24 03:12:31,065 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51136.43....
# 2024-02-24 03:12:31,072 - grid_995789 - INFO - [2024-02-23 14:20:00] filling 5 orders...
# 2024-02-24 03:12:31,078 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,084 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:31,085 - grid_995789 - INFO - [2024-02-23 14:30:00] filling 1 orders...
# 2024-02-24 03:12:31,091 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:31,091 - grid_995789 - INFO - [2024-02-23 14:35:00] filling 4 orders...
# 2024-02-24 03:12:31,094 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 50891.44....
# 2024-02-24 03:12:31,100 - grid_995789 - INFO - [2024-02-23 14:40:00] filling 5 orders...
# 2024-02-24 03:12:31,106 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.33 (below threshold 0.50).
# 2024-02-24 03:12:31,106 - grid_995789 - INFO - [2024-02-23 14:45:00] filling 2 orders...
# 2024-02-24 03:12:31,112 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,113 - grid_995789 - INFO - [2024-02-23 14:50:00] filling 1 orders...
# 2024-02-24 03:12:31,116 - grid_995789 - INFO - stop loss are triggered at 51081.77.
# 2024-02-24 03:12:31,116 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:31,118 - grid_995789 - INFO - closing out net position of -0.00392 BTCUSDT....
# 2024-02-24 03:12:31,120 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51100.6....
# 2024-02-24 03:12:31,127 - grid_995789 - INFO - [2024-02-23 14:55:00] filling 6 orders...
# 2024-02-24 03:12:31,133 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.32 (below threshold 0.50).
# 2024-02-24 03:12:31,133 - grid_995789 - INFO - [2024-02-23 15:00:00] filling 3 orders...
# 2024-02-24 03:12:31,139 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.29 (below threshold 0.50).
# 2024-02-24 03:12:31,140 - grid_995789 - INFO - [2024-02-23 15:05:00] filling 1 orders...
# 2024-02-24 03:12:31,143 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 50990.41....
# 2024-02-24 03:12:31,149 - grid_995789 - INFO - [2024-02-23 15:10:00] filling 2 orders...
# 2024-02-24 03:12:31,156 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.26 (below threshold 0.50).
# 2024-02-24 03:12:31,156 - grid_995789 - INFO - [2024-02-23 15:15:00] filling 2 orders...
# 2024-02-24 03:12:31,161 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.28 (below threshold 0.50).
# 2024-02-24 03:12:31,167 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.24 (below threshold 0.50).
# 2024-02-24 03:12:31,168 - grid_995789 - INFO - [2024-02-23 15:25:00] filling 1 orders...
# 2024-02-24 03:12:31,174 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.25 (below threshold 0.50).
# 2024-02-24 03:12:31,180 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.20 (below threshold 0.50).
# 2024-02-24 03:12:31,187 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.20 (below threshold 0.50).
# 2024-02-24 03:12:31,187 - grid_995789 - INFO - [2024-02-23 15:40:00] filling 1 orders...
# 2024-02-24 03:12:31,194 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.22 (below threshold 0.50).
# 2024-02-24 03:12:31,200 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.24 (below threshold 0.50).
# 2024-02-24 03:12:31,206 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.27 (below threshold 0.50).
# 2024-02-24 03:12:31,212 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.27 (below threshold 0.50).
# 2024-02-24 03:12:31,219 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.30 (below threshold 0.50).
# 2024-02-24 03:12:31,225 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:31,228 - grid_995789 - INFO - stop loss are triggered at 50782.01.
# 2024-02-24 03:12:31,229 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:31,232 - grid_995789 - INFO - closing out net position of 0.00784 BTCUSDT....
# 2024-02-24 03:12:31,234 - grid_995789 - INFO - creating 10 grid orders of 0.00197 BTCUSDT at grid center price 50695.15....
# 2024-02-24 03:12:31,241 - grid_995789 - INFO - [2024-02-23 16:15:00] filling 2 orders...
# 2024-02-24 03:12:31,244 - grid_995789 - INFO - status: NEUTRAL.
# 2024-02-24 03:12:31,245 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:31,247 - grid_995789 - INFO - creating 10 grid orders of 0.00197 BTCUSDT at grid center price 50697.99....
# 2024-02-24 03:12:31,254 - grid_995789 - INFO - [2024-02-23 16:20:00] filling 5 orders...
# 2024-02-24 03:12:31,260 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:31,261 - grid_995789 - INFO - [2024-02-23 16:25:00] filling 1 orders...
# 2024-02-24 03:12:31,267 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:31,273 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.40 (below threshold 0.50).
# 2024-02-24 03:12:31,279 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:31,287 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:31,291 - grid_995789 - INFO - stop loss are triggered at 50947.63.
# 2024-02-24 03:12:31,292 - grid_995789 - INFO - cancelling all orders.....
# 2024-02-24 03:12:31,294 - grid_995789 - INFO - closing out net position of -0.00788 BTCUSDT....
# 2024-02-24 03:12:31,297 - grid_995789 - INFO - creating 10 grid orders of 0.00196 BTCUSDT at grid center price 51023.52....
# 2024-02-24 03:12:31,305 - grid_995789 - INFO - [2024-02-23 16:50:00] filling 2 orders...
# 2024-02-24 03:12:31,312 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:31,319 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:31,325 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,326 - grid_995789 - INFO - [2024-02-23 17:05:00] filling 1 orders...
# 2024-02-24 03:12:31,334 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:31,341 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,348 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:31,355 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:31,356 - grid_995789 - INFO - [2024-02-23 17:25:00] filling 1 orders...
# 2024-02-24 03:12:31,363 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.43 (below threshold 0.50).
# 2024-02-24 03:12:31,370 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:31,376 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.48 (below threshold 0.50).
# 2024-02-24 03:12:31,377 - grid_995789 - INFO - [2024-02-23 17:40:00] filling 1 orders...
# 2024-02-24 03:12:31,384 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.45 (below threshold 0.50).
# 2024-02-24 03:12:31,391 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.44 (below threshold 0.50).
# 2024-02-24 03:12:31,398 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.39 (below threshold 0.50).
# 2024-02-24 03:12:31,405 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,411 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.36 (below threshold 0.50).
# 2024-02-24 03:12:31,420 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:31,426 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,433 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,440 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.41 (below threshold 0.50).
# 2024-02-24 03:12:31,447 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.37 (below threshold 0.50).
# 2024-02-24 03:12:31,454 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,461 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.35 (below threshold 0.50).
# 2024-02-24 03:12:31,468 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.33 (below threshold 0.50).
# 2024-02-24 03:12:31,475 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.33 (below threshold 0.50).
# 2024-02-24 03:12:31,481 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.32 (below threshold 0.50).
# 2024-02-24 03:12:31,489 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.34 (below threshold 0.50).
# 2024-02-24 03:12:31,496 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,503 - grid_995789 - INFO - state: ACTIVE, hurst_exponent is 0.38 (below threshold 0.50).
# 2024-02-24 03:12:31,508 - grid_995789 - INFO - closing out net position of -0.00588 BTCUSDT....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lok419/Desktop/JupyterLab/Trading/strategy_v3/notebook/Grid Trading Sctrach.ipynb Cell 14 line 5
#       <a href='vscode-notebook-cell:/Users/lok419/Desktop/JupyterLab/Trading/strategy_v3/notebook/Grid%20Trading%20Sctrach.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     strategy.execute(data)
#       <a href='vscode-notebook-cell:/Users/lok419/Desktop/JupyterLab/Trading/strategy_v3/notebook/Grid%20Trading%20Sctrach.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> strategy.close_out_positions('close', data['Close'], data['Date'])
# ----> <a href='vscode-notebook-cell:/Users/lok419/Desktop/JupyterLab/Trading/strategy_v3/notebook/Grid%20Trading%20Sctrach.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> strategy.summary(True)
#
# File ~/Desktop/JupyterLab/Trading/strategy_v3/Strategy/GridArithmeticStrategy.py:425, in GridArithmeticStrategy.summary(self, plot_orders)
#     422         else:
#     423             color = 'red'
# --> 425         fig.add_shape(type='line', x0=grid_min_dt, x1=grid_max_dt, y0=grid, y1=grid, line=dict(color=color, dash='dash'), row=1, col=1)
#     427 filled_orders = df_orders[df_orders['status'] == 'FILLED']
#     428 filled_orders_buy = filled_orders[filled_orders['side'] == 'BUY']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:24234, in Figure.add_shape(self, arg, editable, fillcolor, fillrule, label, layer, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, name, opacity, path, showlegend, templateitemname, type, visible, x0, x1, xanchor, xref, xsizemode, y0, y1, yanchor, yref, ysizemode, row, col, secondary_y, exclude_empty_subplots, **kwargs)
#   24200 from plotly.graph_objs import layout as _layout
#   24202 new_obj = _layout.Shape(
#   24203     arg,
#   24204     editable=editable,
#    (...)
#   24232     **kwargs,
#   24233 )
# > 24234 return self._add_annotation_like(
#   24235     "shape",
#   24236     "shapes",
#   24237     new_obj,
#   24238     row=row,
#   24239     col=col,
#   24240     secondary_y=secondary_y,
#   24241     exclude_empty_subplots=exclude_empty_subplots,
#   24242 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/basedatatypes.py:1605, in BaseFigure._add_annotation_like(self, prop_singular, prop_plural, new_obj, row, col, secondary_y, exclude_empty_subplots)
#    1602     xref, yref = map(lambda t: _add_domain(*t), zip(["x", "y"], [xref, yref]))
#    1603     new_obj.update(xref=xref, yref=yref)
# -> 1605 self.layout[prop_plural] += (new_obj,)
#    1606 # The 'new_obj.xref' and 'new_obj.yref' parameters need to be reset otherwise it
#    1607 # will appear as if user supplied yref params when looping through subplots and
#    1608 # will force annotation to be on the axis of the last drawn annotation
#    1609 # i.e. they all end up on the same axis.
#    1610 new_obj.update(xref=None, yref=None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/basedatatypes.py:5912, in BaseLayoutType.__setitem__(self, prop, value)
#    5909 match = self._subplot_re_match(prop)
#    5910 if match is None:
#    5911     # Set as ordinary property
# -> 5912     super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5913 else:
#    5914     # Set as subplotid property
#    5915     self._set_subplotid_prop(prop, value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/basedatatypes.py:4870, in BasePlotlyType.__setitem__(self, prop, value)
#    4868 # ### Handle compound array property ###
#    4869 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
# -> 4870     self._set_array_prop(prop, value)
#    4872 # ### Handle simple property ###
#    4873 else:
#    4874     self._set_prop(prop, value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/basedatatypes.py:5351, in BasePlotlyType._set_array_prop(self, prop, val)
#    5348 # Import value
#    5349 # ------------
#    5350 validator = self._get_validator(prop)
# -> 5351 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5353 # Save deep copies of current and new states
#    5354 # ------------------------------------------
#    5355 curr_val = self._compound_array_props.get(prop, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:2574, in CompoundArrayValidator.validate_coerce(self, v, skip_invalid)
#    2572 for v_el in v:
#    2573     if isinstance(v_el, self.data_class):
# -> 2574         res.append(self.data_class(v_el))
#    2575     elif isinstance(v_el, dict):
#    2576         res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/graph_objs/layout/_shape.py:1303, in Shape.__init__(self, arg, editable, fillcolor, fillrule, label, layer, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, name, opacity, path, showlegend, templateitemname, type, visible, x0, x1, xanchor, xref, xsizemode, y0, y1, yanchor, yref, ysizemode, **kwargs)
#    1294             raise ValueError(
#    1295                 """\
#    1296 The first argument to the plotly.graph_objs.layout.Shape
#    1297 constructor must be a dict or
#    1298 an instance of :class:`plotly.graph_objs.layout.Shape`"""
#    1299             )
#    1301         # Handle skip_invalid
#    1302         # -------------------
# -> 1303         self._skip_invalid = kwargs.pop("skip_invalid", False)
#    1304         self._validate = kwargs.pop("_validate", True)
#    1306         # Populate data dict with properties
#    1307         # ----------------------------------
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/plotly/basedatatypes.py:4930, in BasePlotlyType.__setattr__(self, prop, value)
#    4917 """
#    4918 Parameters
#    4919 ----------
#    (...)
#    4926 None
#    4927 """
#    4928 if prop.startswith("_") or hasattr(self, prop) or prop in self._valid_props:
#    4929     # Let known properties and private properties through
# -> 4930     super(BasePlotlyType, self).__setattr__(prop, value)
#    4931 else:
#    4932     # Raise error on unknown public properties
#    4933     self._raise_on_invalid_property_error()(prop)
#
# KeyboardInterrupt:

# %% [markdown]
# # Execute Strategy

# %%
strategy = GridArithmeticStrategy(
    instrument = 'BTCUSDT',
    interval = '5m',
    grid_size = 5,
    vol_lookback = 30,
    vol_grid_scale = 0.4,
    vol_stoploss_scale = 7,
    position_size = 20,
    hurst_exp_threshold = 0.5
)

strategy = GridArithmeticStrategy(
    instrument = 'BTCUSDT',
    interval = '5m',
    grid_size = 5,
    vol_lookback = 30,
    vol_grid_scale = 5,
    vol_stoploss_scale = 7,
    position_size = 10,
    hurst_exp_threshold = 1
)

strategy.set_price_decimal(2)
strategy.set_qty_decimal(5)
strategy.set_data_loder(DataLoaderBinance())
strategy.set_executor(ExecutorBinance())

# %%
while True:
    try:
        strategy.load_data('1 Days Ago')
        df = strategy.df.copy()
        data = df.iloc[-1]
        dt_now = pd.to_datetime(datetime.now(timezone.utc)).replace(tzinfo=None)
        interval = df['Date'].diff().iloc[-1].seconds
        since_last = (dt_now - data['Date']).seconds
        assert since_last <= interval
        strategy.execute(data)        
        sleep(30)
    except:
        strategy.cancel_all_orders()
        strategy.close_out_positions('close', data['Close'], data['Date'])
# Out:
# 2024-02-23 02:27:24,188 - grid_837465 - INFO - creating 10 grid orders of 0.00019 BTCUSDT at grid center price 51627.99....
# 2024-02-23 02:27:27,620 - grid_837465 - INFO - cancelling all orders.....
# 2024-02-23 02:27:28,675 - grid_837465 - INFO - nothing to close out because of no oustanding positions....
# 2024-02-23 02:27:29,065 - grid_837465 - INFO - creating 10 grid orders of 0.00019 BTCUSDT at grid center price 51627.99....
# 2024-02-23 02:27:40,459 - grid_837465 - INFO - cancelling all orders.....
# 2024-02-23 02:27:41,546 - grid_837465 - INFO - nothing to close out because of no oustanding positions....
# 2024-02-23 02:27:41,948 - grid_837465 - INFO - creating 10 grid orders of 0.00019 BTCUSDT at grid center price 51621.37....

# %%
strategy.close_out_positions()
# Out:
# 2024-02-23 02:11:53,885 - grid_982381 - INFO - [2024-02-22 18:11:53] nothing to close out because no oustanding positions....

# %%
input('s')
# Out:
# 'dd'
