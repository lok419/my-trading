# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from account.Binance import Binance
import pandas as pd
import numpy as np
import warnings
from tqdm import tqdm
import cvxpy as cp
from utils.logging import get_logger
from utils.data_helper import *
from utils.db import *
from strategy_v3.Strategy import ExchangeArbitrageStrategy

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.options.display.float_format = "{:,.4f}".format
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Expermental Arbitrage strategy in Binance
#
# 1. Get bid/ask price for all active currency pairs in Binance and presents in a matrix $Q$
#
# 2. Transform the price to negative log price (Given converison from currency A->B->C = log(p1*p2) ~= log(p1) + log(p2))
#
# 3. Solve the optimization follow classic Traveling Salesmen Problem (TSP), but removing the constraints that all nodes needs to be visited once
#
# - We want to find a closed loop where the sum of path values are negative
#
# - Input $X$ is the nxn binary matrix (n is number of assets), 1 represents trade from currency x -> y
#
# - Minimize $X$ dot $Q$
#
# Reference: https://nbviewer.org/github/rcroessmann/sharing_public/blob/master/arbitrage_identification.ipynb

# %%
strategy = ExchangeArbitrageStrategy(zero_fees=False, max_trades=5, bid_ask_min=2, min_pnl=0)
strategy.set_strategy_id("qa")
strategy.load_data()
strategy.optimize()
#df_trades = strategy.df_trades
#df_trades
# Out:
# 2025-02-03 02:53:48,104 - 739184 - INFO - trade_size: 50
# 2025-02-03 02:53:48,111 - 739184 - INFO - bid_ask_min: 2 ($100)
# 2025-02-03 02:53:48,112 - 739184 - INFO - zero_fees: False
# 2025-02-03 02:53:48,130 - 739184 - INFO - max_trades: 5
# 2025-02-03 02:53:48,137 - 739184 - INFO - min_pnl: 0bps
# 2025-02-03 02:53:48,142 - 739184 - INFO - is_execute: False
# 2025-02-03 02:53:48,330 - qa - INFO - {'USDT': 50, 'ETH': 0.0005149006851834908, 'BTC': 0.017065108508492452}
# 2025-02-03 02:53:48,434 - qa - INFO - Removed 104 out of 1338 symbols given both bid/ask are non-tradable <$100
# 2025-02-03 02:53:48,512 - qa - INFO - 346 bid/ask quotes are skipped given size <$100.
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Feb 03 02:53:48 AM: Your problem has 152881 variables, 5 constraints, and 0 parameters.
# (CVXPY) Feb 03 02:53:48 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 03 02:53:48 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 03 02:53:48 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 03 02:53:48 AM: Compiling problem (target solver=SCIPY).
# (CVXPY) Feb 03 02:53:48 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIPY
# (CVXPY) Feb 03 02:53:48 AM: Applying reduction Dcp2Cone
# (CVXPY) Feb 03 02:53:48 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 03 02:53:48 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 03 02:53:49 AM: Applying reduction SCIPY
# (CVXPY) Feb 03 02:53:49 AM: Finished problem compilation (took 6.036e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 03 02:53:49 AM: Invoking solver SCIPY  to obtain a solution.
# Solver terminated with message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 03 02:53:54 AM: Problem status: optimal
# (CVXPY) Feb 03 02:53:54 AM: Optimal value: 0.000e+00
# (CVXPY) Feb 03 02:53:54 AM: Compilation took 6.036e-01 seconds
# (CVXPY) Feb 03 02:53:54 AM: Solver (including time spent in interface) took 5.663e+00 seconds
# 2025-02-03 02:53:54,916 - qa - INFO - CVXPY - Status: optimal
# 2025-02-03 02:53:54,917 - qa - INFO - CVXPY - Optimal value: 0.0
# 2025-02-03 02:53:54,924 - qa - INFO - Total PNL: 0.00bps
# 2025-02-03 02:53:54,934 - qa - INFO - No optimal trades found, end here.
# False

# %%
# duck("binance_arb_zero_fees", read_only=False).query(f"delete from trades where price_time::date <= '{datetime.today() - BDay(0):%Y-%m-%d}'")
# Out:
#    Count
# 0  27563

# %% [markdown]
# # Summary of strategy
#
# ###  breakdown the pnl slippage by
# 1. price slippage => difference between theoretical price and fill price
#     - This can be improved by looking into order books and derive a fair market price based on trade size
#     - Or just remove ccys with bid/ask notional smaller than x% of trade size
#
# 2. qty slippage => ccy might not be fully executed when baseAsset is not from_asset
#     - Could mitigate by increase the trade size
#
# 3. commission
#     - Limit the number of trades in optimization

# %%
df_trade_ccy_price = pd.DataFrame({
    'trade_ccy': ['USDT', 'ETH', 'BTC'], 
    'price': [1, float(Binance().client.get_avg_price(symbol="ETHUSDT")['price']), float(Binance().client.get_avg_price(symbol="BTCUSDT")['price'])]}
)

# %%
db = duck("binance_arb_zero_fees")
db.query("""--sql
    select
        price_time::date as "date"
        , epoch(price_time)::int as id
        , strftime(price_time, '%Y-%m-%d %H:%M:%S') as time
        , 10000 * (product(mkt_price_w_fee) - 1) as pnl_net
        , 10000 * (product(mkt_price) - 1) as pnl_gross
        , pnl_gross - pnl_net as fees
        , count(1) as num_trades
        , string_agg(from_asset, ', ') as ccy
        , bool_or(from_asset in ('USDT', 'ETH', 'BTC')) as tradable                       
    from trades         
    where 
        1=1                
    group by price_time      
    order by price_time desc    
    limit 20
""")
# Out:
#          date          id                 time  pnl_net  pnl_gross    fees  \
# 0  2025-02-04  1738632962  2025-02-04 01:36:01   0.8078    30.8691 30.0614
# 1  2025-02-04  1738628660  2025-02-04 00:24:20  12.6425    42.7409 30.0984
# 2  2025-02-04  1738628546  2025-02-04 00:22:25   3.4399    33.5102 30.0703
# 3  2025-02-03  1738611555  2025-02-03 19:39:15  12.3516    41.9455 29.5939
# 4  2025-02-03  1738611526  2025-02-03 19:38:46  10.7029    40.7941 30.0912
# 5  2025-02-03  1738611502  2025-02-03 19:38:22   4.8825    34.9571 30.0746
# 6  2025-02-03  1738609756  2025-02-03 19:09:16  14.0548    44.1579 30.1031
# 7  2025-02-03  1738609710  2025-02-03 19:08:30  24.5587    54.6924 30.1337
# 8  2025-02-03  1738605254  2025-02-03 17:54:14   4.2489    34.3224 30.0736
# 9  2025-02-03  1738602733  2025-02-03 17:12:12  12.7316    42.8295 30.0979
# 10 2025-02-03  1738594807  2025-02-03 15:00:07  13.0451    32.5998 19.5547
# 11 2025-02-03  1738593076  2025-02-03 14:31:16   2.0965    31.6606 29.5641
# 12 2025-02-03  1738592965  2025-02-03 14:29:24   2.2580    31.8222 29.5642
# 13 2025-02-03  1738591815  2025-02-03 14:10:15  18.7495    48.8665 30.1170
# 14 2025-02-03  1738591757  2025-02-03 14:09:17   9.2688    39.3575 30.0887
# 15 2025-02-03  1738591694  2025-02-03 14:08:14   4.3818    33.9532 29.5714
# 16 2025-02-03  1738591659  2025-02-03 14:07:39   2.9630    32.5295 29.5665
# 17 2025-02-03  1738591639  2025-02-03 14:07:18   2.9630    32.5295 29.5665
# 18 2025-02-03  1738591617  2025-02-03 14:06:57   7.5622    37.1421 29.5799
# 19 2025-02-03  1738584734  2025-02-03 12:12:14   2.3890    32.4560 30.0670
#
#     num_trades                          ccy  tradable
# 0            3               ETH, PLN, USDT      True
# 1            3              EGLD, USDT, RON      True
# 2            3              EGLD, USDT, RON      True
# 3            5  ETH, UAH, USDT, FDUSD, USDC      True
# 4            3               ETH, UAH, USDT      True
# 5            5    ETH, UAH, USDT, EURI, EUR      True
# 6            3               ETH, UAH, USDT      True
# 7            3               ETH, UAH, USDT      True
# 8            3               BTC, MXN, USDT      True
# 9            3               TRX, WIN, USDT      True
# 10           3              PLN, USDC, USDT      True
# 11           4         TRX, WIN, USDT, USDC      True
# 12           5  FDUSD, USDC, TRX, WIN, USDT      True
# 13           5    EUR, TRX, WIN, USDT, EURI      True
# 14           5    EUR, TRX, WIN, USDT, EURI      True
# 15           4         TRX, WIN, USDT, USDC      True
# 16           4         TRX, WIN, USDT, USDC      True
# 17           4         TRX, WIN, USDT, USDC      True
# 18           4         TRX, WIN, USDT, USDC      True
# 19           3               MXN, USDT, XRP      True

# %%
db = duck("binance_arb")
db.query("""--sql
    select
        price_time::date as "date"
        , epoch(price_time)::int as id
        , strftime(price_time, '%Y-%m-%d %H:%M:%S') as time
        , 10000 * (product(mkt_price_w_fee) - 1) as pnl_net
        , 10000 * (product(mkt_price) - 1) as pnl_gross
        , pnl_gross - pnl_net as fees
        , count(1) as num_trades
        , string_agg(from_asset, ', ') as ccy
        , bool_or(from_asset in ('USDT', 'ETH', 'BTC')) as tradable                       
    from trades         
    where 
        1=1                
    group by price_time       
    order by price_time desc    
    limit 20
""")
# Out:
#          date          id                 time  pnl_net  pnl_gross    fees  \
# 0  2025-02-03  1738578668  2025-02-03 10:31:07   0.2833    40.3848 40.1015
# 1  2025-02-03  1738578625  2025-02-03 10:30:24  30.1942    70.4153 40.2211
# 2  2025-02-03  1738577249  2025-02-03 10:07:28 113.2836   152.8221 39.5385
# 3  2025-01-29  1738164126  2025-01-29 15:22:05   0.0034     0.0034  0.0000
# 4  2025-01-28  1738101186  2025-01-28 21:53:05  -0.0007    -0.0007  0.0000
# 5  2025-01-28  1738067766  2025-01-28 12:36:06   0.0003     0.0003  0.0000
# 6  2025-01-28  1738067165  2025-01-28 12:26:04   0.0003     0.0003  0.0000
# 7  2025-01-28  1738065005  2025-01-28 11:50:05  -0.0001    -0.0001  0.0000
# 8  2025-01-28  1738055046  2025-01-28 09:04:05  10.9597    51.1041 40.1444
# 9  2025-01-28  1738030805  2025-01-28 02:20:04   0.0040     0.0040  0.0000
# 10 2025-01-27  1738015146  2025-01-27 21:59:06  -0.0003    -0.0003  0.0000
# 11 2025-01-26  1737921186  2025-01-26 19:53:05  -0.0001    -0.0001  0.0000
# 12 2025-01-26  1737891006  2025-01-26 11:30:05  -0.0001    -0.0001  0.0000
# 13 2025-01-25  1737836705  2025-01-25 20:25:04  -0.0009    -0.0009  0.0000
# 14 2025-01-23  1737667870  2025-01-23 21:31:09   0.0040     0.0040  0.0000
# 15 2025-01-23  1737665105  2025-01-23 20:45:05   0.0040     0.0040  0.0000
# 16 2025-01-23  1737634446  2025-01-23 12:14:06   0.0080     0.0080  0.0000
# 17 2025-01-23  1737631565  2025-01-23 11:26:05   0.0070     0.0070  0.0000
# 18 2025-01-23  1737623585  2025-01-23 09:13:04   0.0052     0.0052  0.0000
# 19 2025-01-23  1737623044  2025-01-23 09:04:04   0.0052     0.0052  0.0000
#
#     num_trades                      ccy  tradable
# 0            4     BTC, USDT, SHIB, JPY      True
# 1            4    BTC, FDUSD, SHIB, JPY      True
# 2            4     BCH, USDC, DYDX, BTC      True
# 3            3        FDUSD, USDT, USDC      True
# 4            3        FDUSD, USDC, USDT      True
# 5            3        FDUSD, USDC, USDT      True
# 6            3        FDUSD, USDC, USDT      True
# 7            3        FDUSD, USDC, USDT      True
# 8            4  FDUSD, SOL, USDT, PENGU      True
# 9            3        FDUSD, USDT, USDC      True
# 10           3        FDUSD, USDC, USDT      True
# 11           3        FDUSD, USDC, USDT      True
# 12           3        FDUSD, USDC, USDT      True
# 13           3        FDUSD, USDC, USDT      True
# 14           3        FDUSD, USDT, USDC      True
# 15           3        FDUSD, USDT, USDC      True
# 16           3        FDUSD, USDT, USDC      True
# 17           3        FDUSD, USDT, USDC      True
# 18           3        FDUSD, USDT, USDC      True
# 19           3        FDUSD, USDT, USDC      True

# %%
db = duck("binance_arb")

# get raw orders
df_orders = db.query("""--sql
    select 
        *            
        , epoch(price_time)::int as id
        , price_time::date as "date"        
        , strftime(price_time, '%Y-%m-%d %H:%M:%S') as time
        , string_agg(distinct from_asset, ', ') over (partition by id, "group" order by "order" rows between unbounded preceding and unbounded following) as ccys        
        , first(from_asset) over (partition by price_time, "group" order by "order" rows between unbounded preceding and unbounded following) as trade_ccy
        , case when to_asset = quoteAsset then fill_price else 1/fill_price end as fill_price_adj                             
    from orders  
    where 1 = 1    
""")

# aggregate Orders to trade level
df_fills = duckdb.query("""--sql
    select
        "date"
        , "time"
        , "id"
        , ccys
        , trade_ccy
        , "order"
        , symbol
        , from_asset
        , to_asset                            
        , avg(mkt_price) as theo_px
        , avg(mkt_price_w_fee) as theo_px_w_fee
        , sum(fill_price_adj * fill_qty) / sum(fill_qty) as fill_px        
        , sum(from_asset_qty) as from_qty
        , sum(to_asset_qty) as to_qty                
        , sum(to_asset_comms_qty) as comms_qty
        , ifnull(lag(sum(to_asset_qty)) over (partition by id order by "order"), from_qty) as start_qty
        , start_qty - from_qty as residual_qty
        , 10000 * (fill_px / theo_px - 1) as px_slippage
        , 10000 * (-residual_qty / start_qty) as qty_slippage
        , 10000 * (-comms_qty / (comms_qty + to_qty)) as comms      
        , 10000 * ((1+px_slippage/10000) * (1+qty_slippage/10000) * (1+comms/10000) - 1) as slippage                                                            
        , count(1) as fills        
    from df_orders    
    group by "date", "time", "id", ccys, trade_ccy, "order", from_asset, to_asset, symbol
    order by id, "order"
""").to_df()

# %%
df_fills_agg = duckdb.query("""--sql
    select
        "date"
        , id
        , "time"
        , ccys
        , t1.trade_ccy
        , first(from_asset) = last(to_asset) as valid
        , sum(fills)::int as fills
        , count(1) as trades        
        , first(from_qty) as from_qty
        , last(to_qty) as to_qty
        , last(to_qty) - first(from_qty) as net_qty
        , net_qty * avg(price) as net_pnl_usd 
        , 10000 * net_qty / first(from_qty) as realized_pnl
        , 10000 * (product(theo_px) - 1) as theo_gross_pnl
        , 10000 * (product(theo_px_w_fee) - 1) as theo_net_pnl                            
        , 10000 * (product(1+px_slippage/10000)-1) as px_slippage
        , 10000 * (product(1+qty_slippage/10000)-1) as qty_slippage
        , 10000 * (product(1+comms/10000)-1) as comms                 

    from df_fills t1
    left join df_trade_ccy_price t2 on t1.trade_ccy = t2.trade_ccy
    group by "date", id, "time", ccys, t1.trade_ccy 
    order by time desc
""").to_df()

df_fills_agg
# Out:
#          date          id                 time  \
# 0  2025-02-03  1738578625  2025-02-03 10:30:24
# 1  2025-02-03  1738577249  2025-02-03 10:07:28
# 2  2025-01-21  1737461405  2025-01-21 12:10:05
# 3  2025-01-21  1737451984  2025-01-21 09:33:04
# 4  2025-01-21  1737431705  2025-01-21 03:55:05
# 5  2025-01-21  1737427205  2025-01-21 02:40:05
# 6  2025-01-21  1737423786  2025-01-21 01:43:06
# 7  2025-01-21  1737418386  2025-01-21 00:13:05
# 8  2025-01-20  1737387365  2025-01-20 15:36:04
# 9  2025-01-20  1737387246  2025-01-20 15:34:05
# 10 2025-01-20  1737370144  2025-01-20 10:49:04
# 11 2025-01-20  1737352867  2025-01-20 06:01:06
# 12 2025-01-20  1737352384  2025-01-20 05:53:04
# 13 2025-01-19  1737248410  2025-01-19 01:00:09
# 14 2025-01-19  1737245825  2025-01-19 00:17:04
# 15 2025-01-18  1737241927  2025-01-18 23:12:06
# 16 2025-01-18  1737235205  2025-01-18 21:20:05
# 17 2025-01-18  1737231545  2025-01-18 20:19:04
# 18 2025-01-18  1737231065  2025-01-18 20:11:05
# 19 2025-01-18  1737230586  2025-01-18 20:03:05
# 20 2025-01-18  1737225605  2025-01-18 18:40:05
# 21 2025-01-18  1737220207  2025-01-18 17:10:06
# 22 2025-01-18  1737208925  2025-01-18 14:02:04
# 23 2025-01-18  1737208565  2025-01-18 13:56:04
# 24 2025-01-18  1737208265  2025-01-18 13:51:04
# 25 2025-01-18  1737202684  2025-01-18 12:18:04
# 26 2025-01-18  1737199324  2025-01-18 11:22:04
# 27 2025-01-18  1737199207  2025-01-18 11:20:06
# 28 2025-01-18  1737191165  2025-01-18 09:06:04
# 29 2025-01-18  1737178745  2025-01-18 05:39:04
# 30 2025-01-18  1737177964  2025-01-18 05:26:04
# 31 2025-01-18  1737174665  2025-01-18 04:31:05
#
#                                      ccys trade_ccy  valid  fills  trades  \
# 0                   BTC, FDUSD, SHIB, JPY       BTC   True     15       4
# 1                    BTC, BCH, USDC, DYDX       BTC   True     62       4
# 2                    USDT, IOTX, JPY, BTC      USDT   True      7       4
# 3                          USDT, XRP, MXN      USDT   True      5       3
# 4                       USDT, USDC, TRUMP      USDT   True      5       3
# 5                          ETH, IOTX, JPY       ETH   True      5       3
# 6                   USDT, EURI, BTC, HIVE      USDT   True      4       4
# 7                    BTC, USDC, PEPE, JPY       BTC   True      5       4
# 8                     BTC, BRL, PEPE, JPY       BTC   True     10       4
# 9                    BTC, USDC, PEPE, JPY       BTC   True      9       4
# 10                        USDT, RON, EGLD      USDT   True      7       3
# 11                   USDT, SNT, BTC, EURI      USDT   True      9       4
# 12                   USDT, VIB, BTC, USDC      USDT   True      6       4
# 13                    USDT, SEI, JPY, BTC      USDT   True      6       4
# 14                   BTC, USDC, PEPE, JPY       BTC   True      4       4
# 15                   USDT, TUSD, BTC, RON      USDT   True      9       4
# 16                   USDT, BTC, JPY, IOTX      USDT   True      6       4
# 17                   USDT, IOTX, JPY, BTC      USDT   True      4       4
# 18                   USDT, IOTX, JPY, BTC      USDT   True      5       4
# 19                   USDT, IOTX, JPY, SEI      USDT   True      5       4
# 20                    BTC, USDC, SEI, JPY       BTC   True      6       4
# 21                        USDT, EGLD, RON      USDT   True      3       3
# 22                   USDT, BTC, JPY, IOTX      USDT   True      5       4
# 23             USDT, PEPE, JPY, BTC, EURI      USDT   True     10       5
# 24             USDT, IOTX, JPY, BTC, USDC      USDT   True      6       5
# 25             USDT, IOTX, JPY, BTC, EURI      USDT   True      6       5
# 26  USDT, EURI, EUR, SHIB, JPY, BNB, TUSD      USDT   True     15       7
# 27            USDT, IOTX, JPY, DOGE, TUSD      USDT   True      8       5
# 28                   USDT, WIN, TRX, USDC      USDT   True      8       4
# 29              USDT, SEI, JPY, BNB, TUSD      USDT   True     13       5
# 30                        USDT, PLN, USDC      USDT   True      4       3
# 31                        USDT, RON, EGLD      USDT   True      4       3
#
#     from_qty  to_qty  net_qty  net_pnl_usd  realized_pnl  theo_gross_pnl  \
# 0     0.0203  0.0203  -0.0000      -2.4832      -12.4654         70.4153
# 1     0.0215  0.0172  -0.0044    -428.0604   -2,024.9112        152.8221
# 2    49.9814 50.1474   0.1659       0.1659       33.1968         97.0209
# 3    49.4000 46.9530  -2.4470      -2.4470     -495.3445         84.9450
# 4    49.0539 48.8510  -0.2029      -0.2029      -41.3712        178.3774
# 5     0.0154  0.0155   0.0001       0.2544       61.6712         89.4338
# 6    49.9248 48.2046  -1.7202      -1.7202     -344.5490        103.9847
# 7     0.0005  0.0005  -0.0000      -0.1493      -29.2303         99.0738
# 8     0.0005  0.0005  -0.0000      -0.1493      -29.2304         90.5819
# 9     0.0005  0.0005   0.0000       0.1454       28.4613        108.2882
# 10   50.0000 48.7452  -1.2548      -1.2548     -250.9590        126.2664
# 11   49.9727 48.5708  -1.4019      -1.4019     -280.5365         90.1658
# 12   49.9583 48.0672  -1.8911      -1.8911     -378.5316        104.8594
# 13   49.9746 49.5423  -0.4323      -0.4323      -86.5132         58.7088
# 14    0.0005  0.0005   0.0000       0.1454       28.4613         73.2493
# 15   49.0273 46.9530  -2.0743      -2.0743     -423.0910         91.1023
# 16   49.6172 49.2867  -0.3305      -0.3305      -66.6156         60.6966
# 17   49.9725 49.7516  -0.2210      -0.2210      -44.2160         47.0378
# 18   49.9615 49.7255  -0.2361      -0.2361      -47.2493         54.2292
# 19   49.9741 49.4828  -0.4912      -0.4912      -98.2915         46.2234
# 20    0.0005  0.0005  -0.0000      -0.4440      -86.9231         44.0829
# 21   49.6860 48.9510  -0.7350      -0.7350     -147.9291         64.8716
# 22   49.4400 49.2913  -0.1487      -0.1487      -30.0685         43.5668
# 23   50.0000 49.3801  -0.6199      -0.6199     -123.9754         44.6673
# 24   49.9962 49.0147  -0.9815      -0.9815     -196.3087         45.9697
# 25   49.9867 49.4496  -0.5371      -0.5371     -107.4527         42.9548
# 26   49.9938 49.0490  -0.9448      -0.9448     -188.9839         44.3643
# 27   49.9943 49.0490  -0.9453      -0.9453     -189.0892         50.7160
# 28   50.0000 48.9804  -1.0196      -1.0196     -203.9177         39.8219
# 29   49.9596 49.0490  -0.9106      -0.9106     -182.2670         60.3597
# 30   50.0000 47.9760  -2.0240      -2.0240     -404.7997         23.9710
# 31   50.0000 48.8961  -1.1039      -1.1039     -220.7893         31.0911
#
#     theo_net_pnl  px_slippage  qty_slippage    comms
# 0        30.1942     -42.2341       -0.2948 -39.9425
# 1       113.2836  -1,790.3484       -0.0773 -38.9428
# 2        56.6943      -6.0647      -17.3306 -39.9197
# 3        54.7214    -316.3797     -238.2282 -29.9700
# 4       158.5394    -185.8366      -11.1613 -19.4905
# 5        59.1960       9.3859       -6.9160 -29.9700
# 6        73.7024    -137.8807     -281.1878 -29.9700
# 7        59.7451     -74.3081      -14.2697 -38.9182
# 8        50.2800     -63.8951      -15.4549 -39.7998
# 9        68.9236     -33.8029       -6.4423 -38.9048
# 10       95.9174    -270.7469      -74.8605 -29.9700
# 11       59.9257    -215.7623     -125.2798 -30.0670
# 12       75.0796    -143.4270     -311.4334 -29.2990
# 13       18.5336     -25.2761      -79.7996 -39.9193
# 14       34.0212      -0.5106       -5.0676 -38.9048
# 15       60.8592     -94.7022     -390.0130 -29.9700
# 16       20.5143     -67.7872      -19.1893 -39.9400
# 17        6.9104       0.9480      -52.0762 -39.8987
# 18       14.0733     -21.6124      -39.7509 -39.8987
# 19        6.0990     -13.6531      -90.7978 -39.9400
# 20        4.9687     -31.8597      -63.7190 -35.3919
# 21       34.7069    -112.4331      -70.3627 -29.9700
# 22        3.4529     -43.2865       -2.9881 -27.0913
# 23        4.5486    -105.2889      -63.2697   0.0000
# 24        6.3473     -37.4416     -204.4955   0.0000
# 25        2.8429     -13.6090     -136.3414   0.0000
# 26        4.2474     -37.8214     -187.8751  -7.5000
# 27       10.5743     -18.2106     -220.7862   0.0000
# 28       10.2335     -65.4959     -178.4450   0.0000
# 29       20.1786     -61.3295     -153.8979 -27.4750
# 30        4.4338     -31.6392     -378.6045 -19.4905
# 31        1.0275    -148.6414      -74.3138 -29.8938

# %%
df_fills[df_fills['id'] == 1738577249]
# Out:
#           date                 time          id                  ccys  \
# 121 2025-02-03  2025-02-03 10:07:28  1738577249  BTC, BCH, USDC, DYDX
# 122 2025-02-03  2025-02-03 10:07:28  1738577249  BTC, BCH, USDC, DYDX
# 123 2025-02-03  2025-02-03 10:07:28  1738577249  BTC, BCH, USDC, DYDX
# 124 2025-02-03  2025-02-03 10:07:28  1738577249  BTC, BCH, USDC, DYDX
#
#     trade_ccy  order    symbol from_asset to_asset  theo_px  theo_px_w_fee  \
# 121       BTC      1    BCHBTC        BTC      BCH 322.3727       322.0503
# 122       BTC      2   BCHUSDC        BCH     USDC 285.0000       284.7292
# 123       BTC      3  DYDXUSDC       USDC     DYDX   1.6518         1.6502
# 124       BTC      4   DYDXBTC       DYDX      BTC   0.0000         0.0000
#
#      fill_px   from_qty     to_qty  comms_qty  start_qty  residual_qty  \
# 121 324.1491     0.0215     6.9690     0.0070     0.0215        0.0000
# 122 280.0761     6.9690 1,949.9962     1.8543     6.9690        0.0000
# 123   1.4122 1,949.9932 2,642.6571     2.5129 1,949.9962        0.0031
# 124   0.0000 2,642.6500     0.0172     0.0000 2,642.6571        0.0071
#
#      px_slippage  qty_slippage    comms    slippage  fills
# 121      55.1059       -0.0000 -10.0000     45.0508      1
# 122    -172.7676       -0.0348  -9.5000   -182.1377      6
# 123  -1,450.4946       -0.0157  -9.5000 -1,458.6300     52
# 124    -282.2468       -0.0268  -9.9998   -291.9904      3

# %% [markdown]
# # Trade the arbitrage pair(s)
# - Trade the pairs with highest pnl
# - The arbitrage loop starts with one existing currency in current portfolios
#
# - commission are included in quote quantity?

# %%
trade_currency = {
    'USDT': 50,
    'ETH':  0.01539456264,
    'BTC': 0.00052979531,
}

# %%
client = Binance().client
balance = client.get_account()
balance = pd.DataFrame(balance['balances'])
balance['free'] = balance['free'].astype(float)
balance['locked'] = balance['locked'].astype(float)
balance = balance[balance['free'] > 0]
balance
# Out:
#      asset       free  locked
# 0      BTC     0.0938  0.0000
# 2      ETH     1.8625  0.0000
# 4      BNB     0.0000  0.0000
# 7      SNT     0.8130  0.0000
# 11    USDT 9,224.2095  0.0000
# 22     TRX     0.0821  0.0000
# 57     VIB     0.3160  0.0000
# 61     XRP     2.7227  0.0000
# 86     ADA     0.0734  0.0000
# 88     XLM    99.9000  0.0000
# 130   TUSD     1.4657  0.0000
# 134   IOTX   102.4500  0.0000
# 143   DENT     0.7540  0.0000
# 158   USDC     3.9854  0.0000
# 183    WIN     0.5803  0.0000
# 197    EUR     0.2972  0.0000
# 200    UAH    53.0812  0.0000
# 202    TRY    28.5318  0.0000
# 205    BCH     0.0000  0.0000
# 208    MXN    29.1001  0.0000
# 210    BRL     0.0001  0.0000
# 213    PLN     3.8884  0.0000
# 215    RON     4.7494  0.0000
# 227    JPY   604.2111  0.0000
# 237   HIVE     0.8760  0.0000
# 239    SOL     4.6596  0.0000
# 279   LUNA     0.0000  0.0000
# 285   EGLD     0.0257  0.0000
# 374   CELO    39.5604  0.0000
# 399    FIS     0.8780  0.0000
# 422     AR     0.0072  0.0000
# 424   SHIB     1.4500  0.0000
# 454   DYDX     0.0071  0.0000
# 525   ETHW     1.3043  0.0000
# 542  WBETH     0.0001  0.0000
# 543    SUI     5.0000  0.0000
# 544   PEPE     3.5600  0.0000
# 549  FDUSD     2.3667  0.0000
# 554    SEI     6.3120  0.0000
# 605   EURI     1.4667  0.0000
# 610   CATI     0.0169  0.0000
# 628  PENGU     0.3180  0.0000
# 637  TRUMP     0.0009  0.0000
